# %% [markdown]
# # Deep Learning vs Machine Learning

# %% [markdown]
#     AI => Artificial Intelligence
#         Create a Machine which is mimicing Human Like Intelligence
#
#         Descriptive Statistics
#             Data Analysis => Analyse the data and trying to understand what happened in the past
#         Inferential Statistics
#             Machine Learning
#                 Supervised      =>  Input + Output => Logic | Features + Target
#                 Unsupervised    =>  Input                   | Features              | Clustering
#                 Reinforcement   =>  Input + Output => Logic + Feedback
#             Deep Learning
#                 ANN
#                 RNN
#                 CNN
#                 NLP
#             LLM Models

# %% [markdown]
#     Imagine you want to teach a computer to identify whether a dish is "Good Biryani" or "Bad Biryani"
#
#     Machine Learning Way:
#         You (the human) manually tell the computer:
#             "If rice grains are separate → Good"
#             "If it has 500g chicken → Good"
#             "If it has saffron color → Good"
#             "If it costs less than ₹200 → Bad"
#         You create rules based on features YOU chose
#         Computer blindly follows these rules
#         Problem: What if good biryani costs ₹250? Your rule fails!
#
#     Deep Learning Way:
#
#         You show the computer 10,000 photos of biryani
#         Half labeled "Good", half labeled "Bad"
#         Computer automatically learns what makes biryani good:
#
#         "Hmm, good biryani has golden color"
#         "Hmm, good biryani has visible chicken pieces"
#         "Hmm, good biryani has certain aroma patterns"
#
#         You NEVER told it these features - it discovered them!

# %% [markdown]
#     ════════════════════════════════════════════════════════════════
#                 MACHINE LEARNING      |      DEEP LEARNING
#     ════════════════════════════════════════════════════════════════
#     Data Needed:  1,000 samples          |  100,000+ samples
#                 (Small data)           |  (MASSIVE data)
#     ────────────────────────────────────────────────────────────────
#     Your Work:    YOU extract features   |  Computer finds features
#                 (Manual labor)         |  (Automatic)
#     ────────────────────────────────────────────────────────────────
#     Example:      "Look for keywords:    |  "Learn language patterns
#                 'free', 'winner'"      |  from 1M emails"
#     ────────────────────────────────────────────────────────────────
#     Hardware:     Normal laptop CPU      |  GPU (Graphics card)
#                 ₹40,000 laptop OK      |  ₹1,00,000+ GPU needed
#     ────────────────────────────────────────────────────────────────
#     Training:     Seconds to minutes     |  Hours to days
#     ────────────────────────────────────────────────────────────────
#     Accuracy:     70-85%                 |  90-99%
#                 (Good enough)          |  (State-of-the-art)
#     ────────────────────────────────────────────────────────────────
#     When to use:  Small data,            |  Large data,
#                 Simple patterns,       |  Complex patterns,
#                 Limited compute        |  High compute available
#     ════════════════════════════════════════════════════════════════

# %% [markdown]
#     # YOU manually define rules
#     if "lottery" in email:
#         spam = True
#     if "prince of Nigeria" in email:
#         spam = True
#     if sender_unknown AND has_attachment:
#         spam = True
#
#     Limitation: Spammers change words → "l0ttery", "pr!nce" → Your rules fail

# %% [markdown]
#     # Network learns patterns from 1 million emails
#     # It discovers:
#     # - Spam emails have certain word combinations
#     # - Spam emails have specific sentence structures
#     # - Spam emails have urgency patterns ("ACT NOW!")
#     # YOU never told it these - it LEARNED!
#     ```
#
#     **Example 2: Recommending Movies**
#
#     **Machine Learning:**
#     - "User watched 3 action movies → Recommend action"
#     - Simple rule-based
#
#     **Deep Learning:**
#     - "User watched Inception, Interstellar, The Prestige"
#     - Network learns: "User likes Christopher Nolan + mind-bending plots + Hans Zimmer music"
#     - Recommends: "Arrival" (similar complex storytelling, even though not Nolan)
#     - **Netflix, YouTube actually use Deep Learning!**

# %% [markdown]
# ## ANN Architecture - The Brain Analogy

# %% [markdown]
#     Before computers, there was the human brain:
#     ```
#     Your brain has 86 BILLION neurons
#     Each neuron connects to 10,000 other neurons
#     Total connections: 860 TRILLION!
#
#     How you learned to recognize your mom:
#     1. As a baby, you saw her face 1000s of times
#     2. Your neurons started forming patterns:
#     - "This face shape appears often"
#     - "This voice is comforting"
#     - "This smell means safety"
#     3. After enough exposure → Instant recognition!
#     4. You can recognize her even in dark, from side angle, or with new hairstyle
#     ```

# %% [markdown]
#     Artificial Neural Networks copy this idea!
#
#     ☕ The Mumbai Chai-Wala Neural Network - Complete Breakdown
#
#     Real-world scenario:** Chai-wala at Mumbai Central Station deciding whether a customer will buy chai.
#
#     BIOLOGICAL BRAIN:                    ARTIFICIAL NEURAL NETWORK:
#     ─────────────────                    ─────────────────────────
#     Eyes (see customer)         →        Input Layer (receives data)
#     Brain processing            →        Hidden Layers (thinking)
#     Decision (sell chai or not) →        Output Layer (final answer)

# %% [markdown]
# ## 🏗️ Detailed ANN Architecture

# %% [markdown]
#     INPUT LAYER                  HIDDEN LAYER 1              HIDDEN LAYER 2           OUTPUT LAYER
#     (What we observe)            (First level thinking)      (Deep thinking)          (Decision)
#
#     Is raining?                       ┌─────┐                    ┌─────┐                ┌─────┐
#     (1) ─────────┬────────────────►│  N1 │──────┬─────────────►│  N5 │────────┬──────►│  O  │
#                     │                  └─────┘      │             └─────┘        │       └─────┘
#     Is morning?     │                 Combines      │            Combines        │         │
#     (1) ─────────┼────────────────► rain+morning │             patterns       │         │
#                     │                               │                            │         ▼
#     Is cold?        │                  ┌─────┐      │             ┌─────┐        │    Probability
#     (1) ─────────┼────────────────►│  N2 │──────┼─────────────►│  N6 │────────┤    Customer will
#                     │                  └─────┘      │             └─────┘        │    buy chai?
#     Looks tired?    │                 Combines      │            Final           │    (0.85 = 85%)
#     (1) ─────────┼────────────────► cold+tired   │             decision       │
#                     │                               │             making         │
#     Weekend?        │                  ┌─────┐      │                            │
#     (0) ─────────┴────────────────►│  N3 │──────┴─────────────────────────────┘
#                                     └─────┘
#                                     Combines
#                                     all patterns

# %% [markdown]
#     # Neuron N1 in Hidden Layer 1
#
#     # Step 1: Receive inputs
#     input_1 = is_raining        # 1 (yes) or 0 (no)
#     input_2 = is_morning        # 1 (yes) or 0 (no)
#     input_3 = is_cold          # 1 (yes) or 0 (no)
#     input_4 = looks_tired      # 1 (yes) or 0 (no)

# %% [markdown]
#     # Step 2: Each input has a WEIGHT (importance)
#     weight_1 = 0.8   # Rain is very important for chai sales
#     weight_2 = 0.6   # Morning is quite important
#     weight_3 = 0.7   # Cold weather is important
#     weight_4 = 0.3   # Tired look is somewhat important

# %% [markdown]
#     # Step 3: Calculate weighted sum
#     weighted_sum = (input_1 * weight_1 +
#                     input_2 * weight_2 +
#                     input_3 * weight_3 +
#                     input_4 * weight_4)

# %% [markdown]
#     # Example: Rainy (1), Morning (1), Cold (1), Not Tired (0)
#     # weighted_sum = (1*0.8 + 1*0.6 + 1*0.7 + 0*0.3) = 2.1

# %% [markdown]
#     # Step 4: Add BIAS (neuron's inherent tendency)
#     bias = 0.5  # Positive bias = neuron is already excited to activate
#     z = weighted_sum + bias  # z = 2.1 + 0.5 = 2.6

# %% [markdown]
#     # Step 5: Apply ACTIVATION FUNCTION (ReLU)
#     # ReLU = "If positive, keep it. If negative, make it 0"
#     if z > 0:
#         output = z      # output = 2.6
#     else:
#         output = 0
#
#     # This output (2.6) goes to NEXT layer neurons!

# %% [markdown]
#     Input
#     Weight
#     Weighted_sum = (input*weight)
#     Bais => 0.5
#
#     Weighted_sum + Bais
#
#     Activation Function
#         ReLU

# %% [markdown]
#     Why Weights and Bias?
#
#         Think of weights as volume knobs on a music mixer:
#         - High weight = "This input is VERY important, turn up the volume!"
#         - Low weight = "This input doesn't matter much, turn down"
#         - Bias = "Even with no input, should this neuron fire?"

# %% [markdown]
#     1. Input Layer
#         Purpose: Receives raw data
#         Neurons: Exactly equal to number of features
#         Example: Image 28x28 pixels = 784 input neurons
#         No activation function here - just passes data forward

# %% [markdown]
#     2. Hidden Layers (Where magic happens!)
#         Purpose: Learn complex patterns
#         Neurons: You decide! (8, 16, 32, 64, 128...)
#         Multiple hidden layers = "Deep" Learning
#         - 1 layer: Learns simple patterns (lines, curves)
#         - 2 layers: Learns combinations (shapes)
#         - 3+ layers: Learns complex concepts (faces, objects)

# %% [markdown]
#     3. Output Layer
#         Purpose: Final prediction
#         Neurons: Based on problem type
#         - Binary classification (Yes/No): 1 neuron with sigmoid
#         - Multi-class (Cat/Dog/Bird): 3 neurons with softmax
#         - Regression (predict number): 1 neuron, no activation

# %% [markdown]
# ## Activation Functions - The Decision Makers

# %% [markdown]
# ### 🎬 Bollywood Director Analogy - Complete Story

# %% [markdown]
#     Imagine you're Karan Johar conducting auditions for your next blockbuster:

# %% [markdown]
#     Actor walks in, performs monologue
#     You rate their performance on a scale
#
#     1. ReLU (Rectified Linear Unit) - "No Negativity Allowed!"
#
#     If performance score > 0 (any good quality):
#         "Great! Let's use your talent!" → Keep the positive score
#     If performance score ≤ 0 (terrible, negative):
#         "Sorry, you're not ready" → Output = 0 (reject)
#
#     Examples:
#     Actor A: Score = 5.2   → ReLU output = 5.2 ✓
#     Actor B: Score = -2.1  → ReLU output = 0   ✗
#     Actor C: Score = 0     → ReLU output = 0   ✗
#     Actor D: Score = 100   → ReLU output = 100 ✓

# %%
def relu(x):
    """
    ReLU keeps positive values as-is, makes negative values zero
    
    Graph looks like:
          |     /
          |    /
          |   /
          |  /
    ______|/_______
          |
    """
    if x > 0:
        return x
    else:
        return 0

# %%
# Examples:
print(relu(5.2))   # 5.2
print(relu(-2.1))  # 0
print(relu(0))     # 0
print(relu(100))   # 100
# Out:
# 5.2
# 0
# 0
# 100

# %% [markdown]
# **Why ReLU is Popular:**
# - ✅ **Fast** to compute (just a comparison)
# - ✅ **Solves vanishing gradient** (more on this Day 2)
# - ✅ **Sparse activation** (many neurons output 0, which is good!)
# - ❌ **Dying ReLU problem**: If a neuron always gets negative input, it outputs 0 forever
#
# **When to use:** Hidden layers in 90% of modern deep networks!

# %% [markdown]
# ### **2. Sigmoid - "Convert to Probability"**

# %% [markdown]
# **Story:**
# ```
# After audition, you rate: "What's the PROBABILITY this actor is perfect for the role?"
#
# Not a yes/no, but a confidence score:
# - Terrible actor:  0.01 (1% chance)  → Almost certainly NO
# - Mediocre actor:  0.50 (50% chance) → Maybe?
# - Good actor:      0.85 (85% chance) → Very likely YES!
# - Perfect actor:   0.99 (99% chance) → Almost certainly YES!
#
# Output is ALWAYS between 0 and 1 (like probability %)

# %% [markdown]
# Sigmoid squashes any number to range [0, 1]
#
#     Graph looks like an S-curve:
#         1.0 |        ___---
#             |    __-/
#         0.5 |  _/
#             | /
#         0.0 |/___________
#
#     Formula: σ(x) = 1 / (1 + e^(-x))
#     where e = 2.71828... (Euler's number)

# %%
import numpy as np

def sigmoid(x):
    """
    Sigmoid squashes any number to range [0, 1]
    
    Graph looks like an S-curve:
        1.0 |        ___---
            |    __-/
        0.5 |  _/
            | /
        0.0 |/___________
            
    Formula: σ(x) = 1 / (1 + e^(-x))
    where e = 2.71828... (Euler's number)
    """
    return 1 / (1 + np.exp(-x))

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
a=100
print(a)
# Out:
# 100

# %%
print('Value of a is:', a)
# Out:
# Value of a is: 10

# %%
print(f'Value of a is: {a}')
# Out:
# Value of a is: 100

# %%
# Examples:
print(f"sigmoid(-10) = {sigmoid(-10):.4f}")  # 0.0000 (almost 0)
print(f"sigmoid(-2)  = {sigmoid(-2):.4f}")   # 0.1192
print(f"sigmoid(0)   = {sigmoid(0):.4f}")    # 0.5000 (exactly middle)
print(f"sigmoid(2)   = {sigmoid(2):.4f}")    # 0.8808
print(f"sigmoid(10)  = {sigmoid(10):.4f}")   # 1.0000 (almost 1)
# Out:
# sigmoid(-10) = 0.0000
# sigmoid(-2)  = 0.1192
# sigmoid(0)   = 0.5000
# sigmoid(2)   = 0.8808
# sigmoid(10)  = 1.0000

# %% [markdown]
# **When to use:**
# - Output layer for **binary classification** (Yes/No, Cat/Dog, Spam/Not Spam)
# - When you need **probability interpretation**

# %% [markdown]
# ### **3. Tanh (Hyperbolic Tangent) - "Rate from -1 to +1"**

# %% [markdown]
# **Story:**
# ```
# Film critic reviewing your movie:
#     -1.0 = "Worst movie ever! Waste of money!"
#     -0.5 = "Pretty bad, wouldn't recommend"
#      0.0 = "Meh, average Bollywood fare"
#     +0.5 = "Good! Worth watching"
#     +1.0 = "MASTERPIECE! Oscar-worthy!"
#
# Zero-centered: Average is 0, not 0.5
# This helps neural networks learn faster!

# %%
import numpy as np

def tanh(x):
    """
    Tanh squashes any number to range [-1, 1]
    
    Graph looks like S-curve centered at 0:
        1.0 |       ___--
            |    _-/
        0.0 |  _/________
            | /
       -1.0 |/
            
    Formula: tanh(x) = (e^x - e^(-x)) / (e^x + e^(-x))
    """
    return np.tanh(x)  # NumPy has built-in function!
    
    # Or manually:
    # return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# Examples:
print(f"tanh(-10) = {tanh(-10):.4f}")  # -1.0000 (almost -1)
print(f"tanh(-2)  = {tanh(-2):.4f}")   # -0.9640
print(f"tanh(0)   = {tanh(0):.4f}")    # 0.0000 (exactly 0)
print(f"tanh(2)   = {tanh(2):.4f}")    # 0.9640
print(f"tanh(10)  = {tanh(10):.4f}")   # 1.0000 (almost 1)
# Out:
# tanh(-10) = -1.0000
# tanh(-2)  = -0.9640
# tanh(0)   = 0.0000
# tanh(2)   = 0.9640
# tanh(10)  = 1.0000

# %% [markdown]
# **Tanh vs Sigmoid:**
# ```
# Sigmoid: Output range [0, 1]      → Good for probabilities
# Tanh:    Output range [-1, 1]     → Good for hidden layers (zero-centered)
#
# Tanh is basically sigmoid shifted and scaled!
# tanh(x) = 2 * sigmoid(2x) - 1
# ```
#
# **When to use:** Hidden layers, especially in RNNs (Day 4)

# %% [markdown]
# ### **4. Softmax - "Who Wins the Award?"**

# %% [markdown]
# **Story:**
# ```
# Filmfare Awards - Best Actor category
# 5 nominees, but only ONE can win:
#
# Actor A (Shah Rukh):  40% chance
# Actor B (Aamir):      30% chance
# Actor C (Salman):     20% chance
# Actor D (Hrithik):    7% chance
# Actor E (Ranbir):     3% chance
#                      ─────────
#                      100% (Must sum to 1!)

# %% [markdown]
# Softmax ensures:
# 1. All outputs are positive (probabilities)
# 2. All outputs sum to exactly 1.0 (100%)
# 3. Highest score gets highest probability

# %%
import numpy as np

def softmax(scores):
    """
    Softmax converts scores to probabilities that sum to 1
    
    Steps:
    1. Exponentiate all scores (make them positive)
    2. Divide each by the sum (normalize to sum=1)
    
    Formula: softmax(x_i) = e^(x_i) / Σ(e^(x_j))
    """
    # Subtract max for numerical stability (prevents overflow)
    exp_scores = np.exp(scores - np.max(scores))
    probabilities = exp_scores / np.sum(exp_scores)
    return probabilities

# Example: 5 actors' raw scores from neural network
raw_scores = np.array([4.2, 3.1, 2.5, 1.0, 0.5])

probabilities = softmax(raw_scores)

print("Actor Scores → Probabilities:")
for i, (score, prob) in enumerate(zip(raw_scores, probabilities)):
    print(f"Actor {i+1}: Score={score:.1f} → Probability={prob:.3f} ({prob*100:.1f}%)")

print(f"\nSum of probabilities: {probabilities.sum():.10f}")  # Always 1.0!

# Output:
# Actor 1: Score=4.2 → Probability=0.484 (48.4%)  ← Highest!
# Actor 2: Score=3.1 → Probability=0.166 (16.6%)
# Actor 3: Score=2.5 → Probability=0.091 (9.1%)
# Actor 4: Score=1.0 → Probability=0.020 (2.0%)
# Actor 5: Score=0.5 → Probability=0.012 (1.2%)
# Sum = 1.000000000
# Out:
# Actor Scores → Probabilities:
# Actor 1: Score=4.2 → Probability=0.632 (63.2%)
# Actor 2: Score=3.1 → Probability=0.211 (21.1%)
# Actor 3: Score=2.5 → Probability=0.116 (11.6%)
# Actor 4: Score=1.0 → Probability=0.026 (2.6%)
# Actor 5: Score=0.5 → Probability=0.016 (1.6%)
#
# Sum of probabilities: 1.0000000000
